# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('/Users/joshuarkarnad/Desktop/Thinkful/Data/WELLCOME/WELLCOME_APCspend2013_forThinkful.csv', encoding='iso-8859-1')

# %%
df = df.dropna()
df.columns = ['ID', 'Publisher', 'Journal','Article', 'Cost']
df['Journal'] = df['Journal'].str.lower()
df['Journal'] = df['Journal'].str.replace(' ', '')
df['Journal'] = df['Journal'].str.replace(',', '')
df['Journal'] = df['Journal'].str.replace(':', '')
df['Cost'] = df['Cost'].str.replace('£', '')
df['Cost'] = df['Cost'].str.replace('$', '')
df['Cost'] = df['Cost'].astype(float)

df.head()
# Out:
#                       ID Publisher                      Journal  \
# 1             PMC3679557       ACS            biomacromolecules
# 2  23043264  PMC3506128        ACS                     jmedchem
# 3    23438330 PMC3646402       ACS                     jmedchem
# 4   23438216 PMC3601604        ACS                     jorgchem
# 5             PMC3579457       ACS  journalofmedicinalchemistry
#
#                                              Article     Cost
# 1  Structural characterization of a Model Gram-ne...  2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   669.64
# 4  Regioselective opening of myo-inositol orthoes...   685.88
# 5  Comparative Structural and Functional Studies ...  2392.20

# %%
df.groupby('Journal').agg(len).sort_values(by = 'Article', ascending = False).head(5)
# Out:
#                                ID  Publisher  Article   Cost
# Journal
# plosone                       197        197      197  197.0
# journalofbiologicalchemistry   52         52       52   52.0
# neuroimage                     28         28       28   28.0
# plospathogens                  24         24       24   24.0
# nucleicacidsresearch           24         24       24   24.0

# %%
df.groupby('Journal')['Cost'].mean()
# Out:
# Journal
# academyofnutritionanddietetics                                                      2379.540000
# acschemicalbiology                                                                  1535.965000
# acschemicalneuroscience                                                             1186.800000
# acsnano                                                                              668.140000
# actacrystallographicasectiond                                                        757.180000
# actacrystallographicasectiondbiologicalcrystallography                               772.580000
# actacrystallographicasectionfstructuralbiologyandcrystallizationcommunications       796.635000
# actacrystallographyd                                                                 774.190000
# actad                                                                                750.160000
# actadermatovenereologica                                                             653.960000
# ...

# %%
df.groupby('Journal')['Cost'].median()
# Out:
# Journal
# academyofnutritionanddietetics                                                      2379.540
# acschemicalbiology                                                                  1294.685
# acschemicalneuroscience                                                             1186.800
# acsnano                                                                              668.140
# actacrystallographicasectiond                                                        757.180
# actacrystallographicasectiondbiologicalcrystallography                               772.580
# actacrystallographicasectionfstructuralbiologyandcrystallizationcommunications       796.635
# actacrystallographyd                                                                 774.190
# actad                                                                                750.160
# actadermatovenereologica                                                             653.960
# ...

# %%
df.groupby('Journal')['Cost'].std().dropna()
# Out:
# Journal
# acschemicalbiology                                                                   500.670917
# acsnano                                                                               35.708892
# actacrystallographicasectiondbiologicalcrystallography                                 1.640488
# actacrystallographicasectionfstructuralbiologyandcrystallizationcommunications        15.605847
# actaneuropathologica                                                                  68.759063
# addiction                                                                            306.481292
# age                                                                                  237.785868
# aids                                                                                 281.067979
# aidscare                                                                             126.415851
# aidsuk                                                                                 0.000000
# ...

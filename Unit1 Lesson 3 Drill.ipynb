# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('/Users/joshuarkarnad/Desktop/Thinkful/Data/NBA Player Data/players_stats.csv')
df['PPG'] = df['PTS'] / df['Games Played']
df['MPG'] = df['MIN'] / df['Games Played']
df.head()
# Out:
#             Name  Games Played   MIN   PTS  FGM  FGA   FG%  3PM  3PA   3P%  \
# 0       AJ Price            26   324   133   51  137  37.2   15   57  26.3
# 1   Aaron Brooks            82  1885   954  344  817  42.1  121  313  38.7
# 2   Aaron Gordon            47   797   243   93  208  44.7   13   48  27.1
# 3  Adreian Payne            32   740   213   91  220  41.4    1    9  11.1
# 4     Al Horford            76  2318  1156  519  965  53.8   11   36  30.6
#
#      ...               Birthdate                    Collage  Experience  \
# 0    ...         October 7, 1986  University of Connecticut           5
# 1    ...        January 14, 1985       University of Oregon           6
# 2    ...      September 16, 1995      University of Arizona           R
# 3    ...       February 19, 1991  Michigan State University           R
# 4    ...            June 3, 1986      University of Florida           7
#
#    Height  Pos  Team  Weight        BMI        PPG        MPG
# ...

# %%
Pos_Facet = sns.FacetGrid(df, row="Pos")

Pos_Facet.map(plt.hist, "PPG", color="steelblue",  lw=0)
plt.subplots_adjust(top=0.9)
Pos_Facet.set_axis_labels('PPG by Pos')
plt.suptitle('Plot: PPG by POS')
sns.despine(trim=True)
plt.show()

sns.set(style="whitegrid")

Pos_PPG = sns.boxplot(x='Pos',y='PPG',data=df,palette='deep')  

plt.title('Plot 4: PPG by POS')

sns.despine(offset=10, trim=True)
Pos_PPG.set(xlabel='', ylabel='PPG')

plt.show()

sns.set(style="whitegrid")

g = sns.factorplot(x="Pos", y="PPG", data=df,
                   size=6, kind="bar", palette="deep", ci=95)
g.despine(left=True)
g.set_ylabels("PPG")
g.set_xlabels("Pos")
plt.title('Barplot: PPG by Pos')
plt.show()

sns.set(style="whitegrid")

g = sns.factorplot(x="Pos", y="PPG", data=df,
                   size=6, kind="point", palette="deep",ci=95,dodge=True,join=False)
g.despine(left=True)
g.set_ylabels("PPG")
g.set_xlabels("Pos")
plt.title('Pointplot: PPG by POS')
plt.show()

# %%
g = sns.lmplot(y='PPG', # Variable 1.
               x='MPG', # Variable 2.
               data=df, # Data
               fit_reg=True, # If set to true, plots a regression line.
               scatter_kws={'alpha':0.4}) # Set points to semi-transparent to see overlaping points.
g.set_ylabels("PPG")
g.set_xlabels("MPG")
plt.title('Scatterplot: PPG by MPG')
plt.show()

g = sns.lmplot(y='PPG', 
               x='MPG',
               data=df, # Data.
               hue='Pos',
               fit_reg=True, 
               ci=False,
               scatter_kws={'alpha':0.4}, 
               palette='deep',
               lowess=True) # Using local weighing to fit a line.
g.set_ylabels("PPG")
g.set_xlabels("MPG")
plt.suptitle('Scatterplot Lowess: PPG by MPG, split by Pos')
plt.subplots_adjust(top=0.9)
plt.show()

g = sns.lmplot(y='PPG', 
               x='MPG',
               data=df, # Data.
               col='Pos',
               fit_reg=True, 
               ci=True,
               scatter_kws={'alpha':0.4}, 
               palette='deep') # Using local weighing to fit a line.
g.set_ylabels("PPG")
g.set_xlabels("MPG")
plt.suptitle('Scatterplot Lowess: PPG by MPG, split by Pos')
plt.subplots_adjust(top=0.9)
plt.show()

# %%
plt.figure(figsize=(10,6))

sns.swarmplot(x='Pos',
              y='PPG',
              data=df,
              dodge=True)

# %%
sns.violinplot(x='Pos', y='PPG', data=df, 
               palette='deep')

# %%
sns.kdeplot(df.PPG, df.MPG)

# %%
sns.jointplot(x='PPG', y='MPG', data=df)
